# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns   
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split , cross_val_score ,GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier ,RandomForestClassifier

# %%
data = pd.read_csv("Churn.csv")

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# Account_Length    0
# Vmail_Message     0
# Day_Mins          0
# Eve_Mins          0
# Night_Mins        0
# Intl_Mins         0
# CustServ_Calls    0
# Churn             0
# Intl_Plan         0
# Vmail_Plan        0
# Day_Calls         0
# Day_Charge        0
# Eve_Calls         0
# Eve_Charge        0
# Night_Calls       0
# Night_Charge      0
# Intl_Calls        0
# Intl_Charge       0
# State             0
# Area_Code         0
# Phone             0
# dtype: int64

# %%
data.describe().T
# Out:
#                  count        mean        std     min     25%     50%     75%  \
# Account_Length  3333.0  101.064806  39.822106    1.00   74.00  101.00  127.00
# Vmail_Message   3333.0    8.099010  13.688365    0.00    0.00    0.00   20.00
# Day_Mins        3333.0  179.775098  54.467389    0.00  143.70  179.40  216.40
# Eve_Mins        3333.0  200.980348  50.713844    0.00  166.60  201.40  235.30
# Night_Mins      3333.0  200.872037  50.573847   23.20  167.00  201.20  235.30
# Intl_Mins       3333.0   10.237294   2.791840    0.00    8.50   10.30   12.10
# CustServ_Calls  3333.0    1.562856   1.315491    0.00    1.00    1.00    2.00
# Day_Calls       3333.0  100.435644  20.069084    0.00   87.00  101.00  114.00
# Day_Charge      3333.0   30.562307   9.259435    0.00   24.43   30.50   36.79
# Eve_Calls       3333.0  100.114311  19.922625    0.00   87.00  100.00  114.00
# Eve_Charge      3333.0   17.083540   4.310668    0.00   14.16   17.12   20.00
# Night_Calls     3333.0  100.107711  19.568609   33.00   87.00  100.00  113.00
# Night_Charge    3333.0    9.039325   2.275873    1.04    7.52    9.05   10.59
# Intl_Calls      3333.0    4.479448   2.461214    0.00    3.00    4.00    6.00
# Intl_Charge     3333.0    2.764581   0.753773    0.00    2.30    2.78    3.27
# Area_Code       3333.0  437.182418  42.371290  408.00  408.00  415.00  510.00
#
#                    max
# Account_Length  243.00
# Vmail_Message    51.00
# Day_Mins        350.80
# Eve_Mins        363.70
# Night_Mins      395.00
# Intl_Mins        20.00
# CustServ_Calls    9.00
# Day_Calls       165.00
# Day_Charge       59.64
# Eve_Calls       170.00
# Eve_Charge       30.91
# Night_Calls     175.00
# Night_Charge     17.77
# Intl_Calls       20.00
# Intl_Charge       5.40
# Area_Code       510.00

# %%
data["State"].unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Account_Length  3333 non-null   int64
#  1   Vmail_Message   3333 non-null   int64
#  2   Day_Mins        3333 non-null   float64
#  3   Eve_Mins        3333 non-null   float64
#  4   Night_Mins      3333 non-null   float64
#  5   Intl_Mins       3333 non-null   float64
#  6   CustServ_Calls  3333 non-null   int64
#  7   Churn           3333 non-null   object
#  8   Intl_Plan       3333 non-null   object
#  9   Vmail_Plan      3333 non-null   object
#  10  Day_Calls       3333 non-null   int64
#  11  Day_Charge      3333 non-null   float64
#  12  Eve_Calls       3333 non-null   int64
#  13  Eve_Charge      3333 non-null   float64
#  14  Night_Calls     3333 non-null   int64
#  15  Night_Charge    3333 non-null   float64
#  16  Intl_Calls      3333 non-null   int64
#  17  Intl_Charge     3333 non-null   float64
#  18  State           3333 non-null   object
#  19  Area_Code       3333 non-null   int64
#  20  Phone           3333 non-null   object
# dtypes: float64(8), int64(8), object(5)
# memory usage: 546.9+ KB

# %%
data.columns
# Out:
# Index(['Account_Length', 'Vmail_Message', 'Day_Mins', 'Eve_Mins', 'Night_Mins',
#        'Intl_Mins', 'CustServ_Calls', 'Churn', 'Intl_Plan', 'Vmail_Plan',
#        'Day_Calls', 'Day_Charge', 'Eve_Calls', 'Eve_Charge', 'Night_Calls',
#        'Night_Charge', 'Intl_Calls', 'Intl_Charge', 'State', 'Area_Code',
#        'Phone'],
#       dtype='object')

# %%
minss =[ 'Day_Mins', 'Eve_Mins', 'Night_Mins',
       'Intl_Mins']

# %%
data[minss]
# Out:
#       Day_Mins  Eve_Mins  Night_Mins  Intl_Mins
# 0        265.1     197.4       244.7       10.0
# 1        161.6     195.5       254.4       13.7
# 2        243.4     121.2       162.6       12.2
# 3        299.4      61.9       196.9        6.6
# 4        166.7     148.3       186.9       10.1
# ...        ...       ...         ...        ...
# 3328     156.2     215.5       279.1        9.9
# 3329     231.1     153.4       191.3        9.6
# 3330     180.8     288.8       191.9       14.1
# 3331     213.8     159.6       139.2        5.0
# 3332     234.4     265.9       241.4       13.7
#
# [3333 rows x 4 columns]

# %%
data["total_mins"] = data[minss].sum(axis=1)

# %%
data["average_mins"]=data[minss].mean(axis=1)

# %%
calls=['Day_Calls','Eve_Calls', 'Night_Calls', 'Intl_Calls']

# %%
calls
# Out:
# ['Day_Calls', 'Eve_Calls', 'Night_Calls', 'Intl_Calls']

# %%
data["average_calls"]=data[calls].mean(axis=1)

# %%
data["total_calls"]=data[calls].sum(axis=1)

# %%
charge = ['Day_Charge','Eve_Charge',
       'Night_Charge','Intl_Charge']

# %%
charge
# Out:
# ['Day_Charge', 'Eve_Charge', 'Night_Charge', 'Intl_Charge']

# %%
data["mean_charge"]=data[charge].mean(axis=1)

# %%
data["total_charge"] = data[charge].sum(axis=1)

# %%
data.T
# Out:
#                     0         1         2         3         4         5     \
# Account_Length       128       107       137        84        75       118
# Vmail_Message         25        26         0         0         0         0
# Day_Mins           265.1     161.6     243.4     299.4     166.7     223.4
# Eve_Mins           197.4     195.5     121.2      61.9     148.3     220.6
# Night_Mins         244.7     254.4     162.6     196.9     186.9     203.9
# Intl_Mins           10.0      13.7      12.2       6.6      10.1       6.3
# CustServ_Calls         1         1         0         2         3         0
# Churn                 no        no        no        no        no        no
# Intl_Plan             no        no        no       yes       yes       yes
# Vmail_Plan           yes       yes        no        no        no        no
# Day_Calls            110       123       114        71       113        98
# Day_Charge         45.07     27.47     41.38      50.9     28.34     37.98
# Eve_Calls             99       103       110        88       122       101
# Eve_Charge         16.78     16.62      10.3      5.26     12.61     18.75
# Night_Calls           91       103       104        89       121       118
# Night_Charge       11.01     11.45      7.32      8.86      8.41      9.18
# Intl_Calls             3         3         5         7         3         6
# Intl_Charge          2.7       3.7      3.29      1.78      2.73       1.7
# State                 KS        OH        NJ        OH        OK        AL
# Area_Code            415       415       415       408       415       510
# Phone           382-4657  371-7191  358-1921  375-9999  330-6626  391-8027
# total_mins         717.2     625.2     539.4     564.8     512.0     654.2
# average_mins       179.3     156.3    134.85     141.2     128.0    163.55
# average_calls      75.75      83.0     83.25     63.75     89.75     80.75
# total_calls          303       332       333       255       359       323
# mean_charge        18.89     14.81   15.5725      16.7   13.0225   16.9025
# total_charge       75.56     59.24     62.29      66.8     52.09     67.61
#
#                     6         7         8         9     ...      3323  \
# Account_Length       121       147       117       141  ...       117
# Vmail_Message         24         0         0        37  ...         0
# Day_Mins           218.2     157.0     184.5     258.6  ...     118.4
# Eve_Mins           348.5     103.1     351.6     222.0  ...     249.3
# Night_Mins         212.6     211.8     215.8     326.4  ...     227.0
# Intl_Mins            7.5       7.1       8.7      11.2  ...      13.6
# CustServ_Calls         3         0         1         0  ...         5
# Churn                 no        no        no        no  ...       yes
# Intl_Plan             no       yes        no       yes  ...        no
# Vmail_Plan           yes        no        no       yes  ...        no
# Day_Calls             88        79        97        84  ...       126
# Day_Charge         37.09     26.69     31.37     43.96  ...     20.13
# Eve_Calls            108        94        80       111  ...        97
# Eve_Charge         29.62      8.76     29.89     18.87  ...     21.19
# Night_Calls          118        96        90        97  ...        56
# Night_Charge        9.57      9.53      9.71     14.69  ...     10.22
# Intl_Calls             7         6         4         5  ...         3
# Intl_Charge         2.03      1.92      2.35      3.02  ...      3.67
# State                 MA        MO        LA        WV  ...        IN
# Area_Code            510       415       408       415  ...       415
# Phone           355-9993  329-9001  335-4719  330-8173  ...  362-5899
# total_mins         786.8     479.0     760.6     818.2  ...     608.3
# average_mins       196.7    119.75    190.15    204.55  ...   152.075
# average_calls      80.25     68.75     67.75     74.25  ...      70.5
# total_calls          321       275       271       297  ...       282
# mean_charge      19.5775    11.725     18.33    20.135  ...   13.8025
# total_charge       78.31      46.9     73.32     80.54  ...     55.21
#
#                     3324      3325      3326      3327      3328      3329  \
# Account_Length       159        78        96        79       192        68
# Vmail_Message          0         0         0         0        36         0
# Day_Mins           169.8     193.4     106.6     134.7     156.2     231.1
# Eve_Mins           197.7     116.9     284.8     189.7     215.5     153.4
# Night_Mins         193.7     243.3     178.9     221.4     279.1     191.3
# Intl_Mins           11.6       9.3      14.9      11.8       9.9       9.6
# CustServ_Calls         1         2         1         2         2         3
# Churn                 no        no        no        no        no        no
# Intl_Plan             no        no        no        no        no        no
# Vmail_Plan            no        no        no        no       yes        no
# Day_Calls            114        99       128        98        77        57
# Day_Charge         28.87     32.88     18.12      22.9     26.55     39.29
# Eve_Calls            105        88        87        68       126        55
# Eve_Charge          16.8      9.94     24.21     16.12     18.32     13.04
# Night_Calls           82       109        92       128        83       123
# Night_Charge        8.72     10.95      8.05      9.96     12.56      8.61
# Intl_Calls             4         4         7         5         6         4
# Intl_Charge         3.13      2.51      4.02      3.19      2.67      2.59
# State                 WV        OH        OH        SC        AZ        WV
# Area_Code            415       408       415       415       415       415
# Phone           377-1164  368-8555  347-6812  348-3830  414-4276  370-3271
# total_mins         572.8     562.9     585.2     557.6     660.7     585.4
# average_mins       143.2   140.725     146.3     139.4   165.175    146.35
# average_calls      76.25      75.0      78.5     74.75      73.0     59.75
# total_calls          305       300       314       299       292       239
# mean_charge        14.38     14.07      13.6   13.0425    15.025   15.8825
# total_charge       57.52     56.28      54.4     52.17      60.1     63.53
#
#                     3330      3331      3332
# Account_Length        28       184        74
# Vmail_Message          0         0        25
# Day_Mins           180.8     213.8     234.4
# Eve_Mins           288.8     159.6     265.9
# Night_Mins         191.9     139.2     241.4
# Intl_Mins           14.1       5.0      13.7
# CustServ_Calls         2         2         0
# Churn                 no        no        no
# Intl_Plan             no       yes        no
# Vmail_Plan            no        no       yes
# Day_Calls            109       105       113
# Day_Charge         30.74     36.35     39.85
# Eve_Calls             58        84        82
# Eve_Charge         24.55     13.57      22.6
# Night_Calls           91       137        77
# Night_Charge        8.64      6.26     10.86
# Intl_Calls             6        10         4
# Intl_Charge         3.81      1.35       3.7
# State                 RI        CT        TN
# Area_Code            510       510       415
# Phone           328-8230  364-6381  400-4344
# total_mins         675.6     517.6     755.4
# average_mins       168.9     129.4    188.85
# average_calls       66.0      84.0      69.0
# total_calls          264       336       276
# mean_charge       16.935   14.3825   19.2525
# total_charge       67.74     57.53     77.01
#
# [27 rows x 3333 columns]

# %%
data =data.drop("Phone",axis=1)

# %%
data.T
# Out:
#                  0      1        2      3        4        5        6     \
# Account_Length    128    107      137     84       75      118      121
# Vmail_Message      25     26        0      0        0        0       24
# Day_Mins        265.1  161.6    243.4  299.4    166.7    223.4    218.2
# Eve_Mins        197.4  195.5    121.2   61.9    148.3    220.6    348.5
# Night_Mins      244.7  254.4    162.6  196.9    186.9    203.9    212.6
# Intl_Mins        10.0   13.7     12.2    6.6     10.1      6.3      7.5
# CustServ_Calls      1      1        0      2        3        0        3
# Churn              no     no       no     no       no       no       no
# Intl_Plan          no     no       no    yes      yes      yes       no
# Vmail_Plan        yes    yes       no     no       no       no      yes
# Day_Calls         110    123      114     71      113       98       88
# Day_Charge      45.07  27.47    41.38   50.9    28.34    37.98    37.09
# Eve_Calls          99    103      110     88      122      101      108
# Eve_Charge      16.78  16.62     10.3   5.26    12.61    18.75    29.62
# Night_Calls        91    103      104     89      121      118      118
# Night_Charge    11.01  11.45     7.32   8.86     8.41     9.18     9.57
# Intl_Calls          3      3        5      7        3        6        7
# Intl_Charge       2.7    3.7     3.29   1.78     2.73      1.7     2.03
# State              KS     OH       NJ     OH       OK       AL       MA
# Area_Code         415    415      415    408      415      510      510
# total_mins      717.2  625.2    539.4  564.8    512.0    654.2    786.8
# average_mins    179.3  156.3   134.85  141.2    128.0   163.55    196.7
# average_calls   75.75   83.0    83.25  63.75    89.75    80.75    80.25
# total_calls       303    332      333    255      359      323      321
# mean_charge     18.89  14.81  15.5725   16.7  13.0225  16.9025  19.5775
# total_charge    75.56  59.24    62.29   66.8    52.09    67.61    78.31
#
#                   7       8       9     ...     3323   3324     3325   3326  \
# Account_Length     147     117     141  ...      117    159       78     96
# Vmail_Message        0       0      37  ...        0      0        0      0
# Day_Mins         157.0   184.5   258.6  ...    118.4  169.8    193.4  106.6
# Eve_Mins         103.1   351.6   222.0  ...    249.3  197.7    116.9  284.8
# Night_Mins       211.8   215.8   326.4  ...    227.0  193.7    243.3  178.9
# Intl_Mins          7.1     8.7    11.2  ...     13.6   11.6      9.3   14.9
# CustServ_Calls       0       1       0  ...        5      1        2      1
# Churn               no      no      no  ...      yes     no       no     no
# Intl_Plan          yes      no     yes  ...       no     no       no     no
# Vmail_Plan          no      no     yes  ...       no     no       no     no
# Day_Calls           79      97      84  ...      126    114       99    128
# Day_Charge       26.69   31.37   43.96  ...    20.13  28.87    32.88  18.12
# Eve_Calls           94      80     111  ...       97    105       88     87
# Eve_Charge        8.76   29.89   18.87  ...    21.19   16.8     9.94  24.21
# Night_Calls         96      90      97  ...       56     82      109     92
# Night_Charge      9.53    9.71   14.69  ...    10.22   8.72    10.95   8.05
# Intl_Calls           6       4       5  ...        3      4        4      7
# Intl_Charge       1.92    2.35    3.02  ...     3.67   3.13     2.51   4.02
# State               MO      LA      WV  ...       IN     WV       OH     OH
# Area_Code          415     408     415  ...      415    415      408    415
# total_mins       479.0   760.6   818.2  ...    608.3  572.8    562.9  585.2
# average_mins    119.75  190.15  204.55  ...  152.075  143.2  140.725  146.3
# average_calls    68.75   67.75   74.25  ...     70.5  76.25     75.0   78.5
# total_calls        275     271     297  ...      282    305      300    314
# mean_charge     11.725   18.33  20.135  ...  13.8025  14.38    14.07   13.6
# total_charge      46.9   73.32   80.54  ...    55.21  57.52    56.28   54.4
#
#                    3327     3328     3329    3330     3331     3332
# Account_Length       79      192       68      28      184       74
# Vmail_Message         0       36        0       0        0       25
# Day_Mins          134.7    156.2    231.1   180.8    213.8    234.4
# Eve_Mins          189.7    215.5    153.4   288.8    159.6    265.9
# Night_Mins        221.4    279.1    191.3   191.9    139.2    241.4
# Intl_Mins          11.8      9.9      9.6    14.1      5.0     13.7
# CustServ_Calls        2        2        3       2        2        0
# Churn                no       no       no      no       no       no
# Intl_Plan            no       no       no      no      yes       no
# Vmail_Plan           no      yes       no      no       no      yes
# Day_Calls            98       77       57     109      105      113
# Day_Charge         22.9    26.55    39.29   30.74    36.35    39.85
# Eve_Calls            68      126       55      58       84       82
# Eve_Charge        16.12    18.32    13.04   24.55    13.57     22.6
# Night_Calls         128       83      123      91      137       77
# Night_Charge       9.96    12.56     8.61    8.64     6.26    10.86
# Intl_Calls            5        6        4       6       10        4
# Intl_Charge        3.19     2.67     2.59    3.81     1.35      3.7
# State                SC       AZ       WV      RI       CT       TN
# Area_Code           415      415      415     510      510      415
# total_mins        557.6    660.7    585.4   675.6    517.6    755.4
# average_mins      139.4  165.175   146.35   168.9    129.4   188.85
# average_calls     74.75     73.0    59.75    66.0     84.0     69.0
# total_calls         299      292      239     264      336      276
# mean_charge     13.0425   15.025  15.8825  16.935  14.3825  19.2525
# total_charge      52.17     60.1    63.53   67.74    57.53    77.01
#
# [26 rows x 3333 columns]

# %%
data["Area_Code"].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area_Code, dtype: int64

# %%
data["Churn"] = data["Churn"].map({"no":0 ,"yes":1})

# %%
data["Intl_Plan"] = data["Intl_Plan"].map({"no":0 ,"yes":1})

# %%
data["Vmail_Plan"] = data["Vmail_Plan"].map({"no":0 ,"yes":1})

# %%
data[["Churn","Intl_Plan","Vmail_Plan"]]
# Out:
#       Churn  Intl_Plan  Vmail_Plan
# 0         0          0           1
# 1         0          0           1
# 2         0          0           0
# 3         0          1           0
# 4         0          1           0
# ...     ...        ...         ...
# 3328      0          0           1
# 3329      0          0           0
# 3330      0          0           0
# 3331      0          1           0
# 3332      0          0           1
#
# [3333 rows x 3 columns]

# %%
lc=LabelEncoder()

# %%
data.loc[:,"State"] = lc.fit_transform(data['State'])
# Out:
# /tmp/ipykernel_20146/3673339916.py:1: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data.loc[:,"State"] = lc.fit_transform(data['State'])

# %%
data["State"].value_counts()
# Out:
# 49    106
# 23     84
# 34     83
# 1      80
# 48     78
# 35     78
# 37     78
# 50     77
# 45     77
# 6      74
# 22     73
# 13     73
# 46     73
# 43     72
# 44     72
# 15     71
# 20     70
# 16     70
# 27     68
# 31     68
# 26     68
# 5      66
# 33     66
# 47     66
# 39     65
# 19     65
# 25     65
# 3      64
# 9      63
# 24     63
# 32     62
# 21     62
# 28     62
# 29     61
# 36     61
# 8      61
# 40     60
# 41     60
# 17     59
# 14     58
# 30     56
# 2      55
# 10     54
# 7      54
# 11     53
# 42     53
# 0      52
# 18     51
# 38     45
# 12     44
# 4      34
# Name: State, dtype: int64

# %%
data.dtypes
# Out:
# Account_Length      int64
# Vmail_Message       int64
# Day_Mins          float64
# Eve_Mins          float64
# Night_Mins        float64
# Intl_Mins         float64
# CustServ_Calls      int64
# Churn               int64
# Intl_Plan           int64
# Vmail_Plan          int64
# Day_Calls           int64
# Day_Charge        float64
# Eve_Calls           int64
# Eve_Charge        float64
# Night_Calls         int64
# Night_Charge      float64
# Intl_Calls          int64
# Intl_Charge       float64
# State               int64
# Area_Code           int64
# total_mins        float64
# average_mins      float64
# average_calls     float64
# total_calls         int64
# mean_charge       float64
# total_charge      float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Account_Length', 'Vmail_Message', 'Day_Mins', 'Eve_Mins', 'Night_Mins',
#        'Intl_Mins', 'CustServ_Calls', 'Churn', 'Intl_Plan', 'Vmail_Plan',
#        'Day_Calls', 'Day_Charge', 'Eve_Calls', 'Eve_Charge', 'Night_Calls',
#        'Night_Charge', 'Intl_Calls', 'Intl_Charge', 'State', 'Area_Code',
#        'total_mins', 'average_mins', 'average_calls', 'total_calls',
#        'mean_charge', 'total_charge'],
#       dtype='object')

# %%
x=data.drop(["Churn"],axis=1)

# %%
y= data["Churn"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=134)

# %%
ms=MinMaxScaler()

# %%
x_train.loc[:,:] = ms.fit_transform(x_train)
x_test.loc[:,:] = ms.fit_transform(x_test)
# Out:
# /tmp/ipykernel_20146/3091689545.py:1: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   x_train.loc[:,:] = ms.fit_transform(x_train)
# /tmp/ipykernel_20146/3091689545.py:2: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   x_test.loc[:,:] = ms.fit_transform(x_test)

# %%
nb = GaussianNB()

# %%
nb.fit(x_train,y_train)
y_pred = nb.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8620689655172413

# %%
cv_results =cross_val_score(nb,x_train,y_train,cv=5)

# %%
cv_results.mean()
# Out:
# 0.8480834229258456

# %%
lda = LinearDiscriminantAnalysis()

# %%
cv_results =cross_val_score(lda,x_train,y_train,cv=5)

# %%
cv_results.mean()
# Out:
# 0.8525841291256475

# %%
lr= LogisticRegression()

# %%
cv_results =cross_val_score(lr,x_train,y_train,cv=5)

# %%
cv_results.mean()
# Out:
# 0.8649619495330649

# %%
sv=SVC()

# %%
cv_results =cross_val_score(sv,x_train,y_train,cv=5)
cv_results.mean()
# Out:
# 0.9099774437675233

# %%
dt = DecisionTreeClassifier()

# %%
cv_results = cross_val_score(dt, x, y, cv = 5, scoring="accuracy")
cv_results.mean()
# Out:
# 0.9492956224590406

# %%
bg = BaggingClassifier(base_estimator=dt, n_estimators= 200)

# %%
cv_results = cross_val_score(bg, x, y, cv = 5, scoring="accuracy")
cv_results.mean()
# Out:
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 0.9765986376181279

# %%
rf =RandomForestClassifier()

# %%
cv_results = cross_val_score(rf, x, y, cv = 5, scoring="accuracy")
cv_results.mean()
# Out:
# 0.977499088293691

# %%
params_rf = {'n_estimators': [50,100,150],
             'max_depth': [8, 16,24],           
             'max_features': ['log2', 'sqrt']}

# %%
grid_rf = GridSearchCV(estimator=rf, param_grid=params_rf, cv = 5, scoring="accuracy")

# %%
grid_rf.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [8, 16, 24],
#                          'max_features': ['log2', 'sqrt'],
#                          'n_estimators': [50, 100, 150]},
#              scoring='accuracy')

# %%
grid_rf.best_params_
# Out:
# {'max_depth': 24, 'max_features': 'sqrt', 'n_estimators': 150}

# %%
grid_rf.best_score_
# Out:
# 0.9748677192908488

# %%
best_model = grid_rf.best_estimator_

# %%
y_pred = best_model.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8620689655172413

# %%
cv_results = cross_val_score(best_model, x, y, cv = 5, scoring="accuracy")
cv_results.mean()
# Out:
# 0.9768989379184282
