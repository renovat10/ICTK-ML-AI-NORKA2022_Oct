# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage,dendrogram,fcluster

# %%
data = pd.read_csv("USArrests.csv")

# %%
data = data.drop("Unnamed: 0",axis=1)

# %%
data.head()
# Out:
#    Murder  Assault  UrbanPop  Rape
# 0    13.2      236        58  21.2
# 1    10.0      263        48  44.5
# 2     8.1      294        80  31.0
# 3     8.8      190        50  19.5
# 4     9.0      276        91  40.6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Murder    50 non-null     float64
#  1   Assault   50 non-null     int64
#  2   UrbanPop  50 non-null     int64
#  3   Rape      50 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 1.7 KB

# %%
data.describe()
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000

# %%
data.columns
# Out:
# Index(['Murder', 'Assault', 'UrbanPop', 'Rape'], dtype='object')

# %%
x=data[['Murder', 'Assault', 'UrbanPop', 'Rape']]

# %%
all_wcss = []
for i in range(1,11):
    km = KMeans(n_clusters=i)
    km.fit(x)
    wcss = km.inertia_
    all_wcss.append(wcss)
# Out:
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
all_wcss
# Out:
# [355807.8216,
#  96399.02814449917,
#  47964.26535714286,
#  34728.629357142854,
#  24417.023523809523,
#  18768.000666666667,
#  15463.473777777777,
#  13329.361976190476,
#  11125.03380952381,
#  9884.692976190474]

# %%
plt.plot(range(1,11),all_wcss)

# %%
km=KMeans(n_clusters=3)
km.fit(x)
# Out:
# /home/amal/Python_projects/ICTK/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
clusters = km.predict(x)

# %%
data["clusters"]=clusters

# %%
data
# Out:
#     Murder  Assault  UrbanPop  Rape  clusters
# 0     13.2      236        58  21.2         2
# 1     10.0      263        48  44.5         2
# 2      8.1      294        80  31.0         2
# 3      8.8      190        50  19.5         1
# 4      9.0      276        91  40.6         2
# 5      7.9      204        78  38.7         1
# 6      3.3      110        77  11.1         0
# 7      5.9      238        72  15.8         2
# 8     15.4      335        80  31.9         2
# 9     17.4      211        60  25.8         1
# 10     5.3       46        83  20.2         0
# 11     2.6      120        54  14.2         0
# 12    10.4      249        83  24.0         2
# 13     7.2      113        65  21.0         0
# 14     2.2       56        57  11.3         0
# 15     6.0      115        66  18.0         0
# 16     9.7      109        52  16.3         0
# 17    15.4      249        66  22.2         2
# 18     2.1       83        51   7.8         0
# 19    11.3      300        67  27.8         2
# 20     4.4      149        85  16.3         1
# 21    12.1      255        74  35.1         2
# 22     2.7       72        66  14.9         0
# 23    16.1      259        44  17.1         2
# 24     9.0      178        70  28.2         1
# 25     6.0      109        53  16.4         0
# 26     4.3      102        62  16.5         0
# 27    12.2      252        81  46.0         2
# 28     2.1       57        56   9.5         0
# 29     7.4      159        89  18.8         1
# 30    11.4      285        70  32.1         2
# 31    11.1      254        86  26.1         2
# 32    13.0      337        45  16.1         2
# 33     0.8       45        44   7.3         0
# 34     7.3      120        75  21.4         0
# 35     6.6      151        68  20.0         1
# 36     4.9      159        67  29.3         1
# 37     6.3      106        72  14.9         0
# 38     3.4      174        87   8.3         1
# 39    14.4      279        48  22.5         2
# 40     3.8       86        45  12.8         0
# 41    13.2      188        59  26.9         1
# 42    12.7      201        80  25.5         1
# 43     3.2      120        80  22.9         0
# 44     2.2       48        32  11.2         0
# 45     8.5      156        63  20.7         1
# 46     4.0      145        73  26.2         1
# 47     5.7       81        39   9.3         0
# 48     2.6       53        66  10.8         0
# 49     6.8      161        60  15.6         1

# %%
sns.scatterplot(x = 'Murder', y = "UrbanPop", data = data, hue = "clusters")
# Out:
# <AxesSubplot: xlabel='Murder', ylabel='UrbanPop'>

# %%
mergings = linkage(x, method = "complete")

# %%
plt.figure(figsize=(10,5))
dendrogram(mergings)
plt.show()

# %%
labels = fcluster(mergings, 85, criterion='distance')

# %%
labels
# Out:
# array([2, 2, 2, 3, 2, 3, 4, 2, 1, 3, 5, 4, 2, 4, 5, 4, 4, 2, 5, 2, 3, 2,
#        5, 2, 3, 4, 4, 2, 5, 3, 2, 2, 1, 5, 4, 3, 3, 4, 3, 2, 5, 3, 3, 4,
#        5, 3, 3, 5, 5, 3], dtype=int32)

# %%
data["hc_clusters"]= labels

# %%
data
# Out:
#     Murder  Assault  UrbanPop  Rape  clusters  hc_clusters
# 0     13.2      236        58  21.2         2            2
# 1     10.0      263        48  44.5         2            2
# 2      8.1      294        80  31.0         2            2
# 3      8.8      190        50  19.5         1            3
# 4      9.0      276        91  40.6         2            2
# 5      7.9      204        78  38.7         1            3
# 6      3.3      110        77  11.1         0            4
# 7      5.9      238        72  15.8         2            2
# 8     15.4      335        80  31.9         2            1
# 9     17.4      211        60  25.8         1            3
# 10     5.3       46        83  20.2         0            5
# 11     2.6      120        54  14.2         0            4
# 12    10.4      249        83  24.0         2            2
# 13     7.2      113        65  21.0         0            4
# 14     2.2       56        57  11.3         0            5
# 15     6.0      115        66  18.0         0            4
# 16     9.7      109        52  16.3         0            4
# 17    15.4      249        66  22.2         2            2
# 18     2.1       83        51   7.8         0            5
# 19    11.3      300        67  27.8         2            2
# 20     4.4      149        85  16.3         1            3
# 21    12.1      255        74  35.1         2            2
# 22     2.7       72        66  14.9         0            5
# 23    16.1      259        44  17.1         2            2
# 24     9.0      178        70  28.2         1            3
# 25     6.0      109        53  16.4         0            4
# 26     4.3      102        62  16.5         0            4
# 27    12.2      252        81  46.0         2            2
# 28     2.1       57        56   9.5         0            5
# 29     7.4      159        89  18.8         1            3
# 30    11.4      285        70  32.1         2            2
# 31    11.1      254        86  26.1         2            2
# 32    13.0      337        45  16.1         2            1
# 33     0.8       45        44   7.3         0            5
# 34     7.3      120        75  21.4         0            4
# 35     6.6      151        68  20.0         1            3
# 36     4.9      159        67  29.3         1            3
# 37     6.3      106        72  14.9         0            4
# 38     3.4      174        87   8.3         1            3
# 39    14.4      279        48  22.5         2            2
# 40     3.8       86        45  12.8         0            5
# 41    13.2      188        59  26.9         1            3
# 42    12.7      201        80  25.5         1            3
# 43     3.2      120        80  22.9         0            4
# 44     2.2       48        32  11.2         0            5
# 45     8.5      156        63  20.7         1            3
# 46     4.0      145        73  26.2         1            3
# 47     5.7       81        39   9.3         0            5
# 48     2.6       53        66  10.8         0            5
# 49     6.8      161        60  15.6         1            3
